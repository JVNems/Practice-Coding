# %% [markdown]
# <a href="https://colab.research.google.com/github/JVNems/Practice-Coding/blob/main/2025_January_16_PUP_Taguig_BSA_4th_Year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import all of the needed modules for data analysis and visualiaztion

import pandas as pd #This line imports the pandas module and gives it a shorter nickname (pd). pandas is a powerful library for working with data in a tabular format (like spreadsheets). It provides tools to read, manipulate, analyze, and clean data.
import numpy as np #This line imports the numpy module and gives it a shorter nickname (np). numpy is essential for numerical computations in Python. It provides tools for working with arrays and matrices of numbers, which are often used in data analysis.
import matplotlib.pyplot as plt #This line imports the pyplot module from the matplotlib library and gives it a shorter nickname (plt). matplotlib is a widely used library for creating static, interactive, and animated visualizations in Python. pyplot provides a simple interface for creating common types of plots like line charts, bar charts, scatter plots, and histograms.
import seaborn as sns #This line imports the seaborn module and gives it a shorter nickname (sns). seaborn builds on top of matplotlib and provides a higher-level interface for creating statistically informative and visually appealing visualizations. It's often used for creating heatmaps, violin plots, and other types of visualizations that are well-suited for exploring relationships in data.
import plotly.express as px #This line imports the plotly.express module and gives it a shorter nickname (px). plotly.express is a library for creating interactive visualizations that can be displayed in web browsers. It offers a variety of plot types and options for customizing the appearance and interactivity of visualizations.

# %%
# !pip install pyreadstat #This line uses !pip which is a command to install Python packages.

import pyreadstat # This package is necessary for reading data from files saved in the .sav format, which is commonly used by statistical software like SPSS.

try:
  df, meta = pyreadstat.read_sav("2025_JAN_16_PUP_TAGUIG_BSA.sav") #This is the core of the data loading process. pyreadstat.read_sav(): This function is from the pyreadstat package and is used to read data from the specified .sav file ("2025_JAN_16_PUP_TAGUIG_BSA.sav").
  df.head(10) #This line, if executed successfully, displays the first 10 rows of the df DataFrame, providing a quick preview of the data.
except FileNotFoundError: #This block is used for error handling. It tries to execute the code within the try section, and if any errors occur, it handles them in the except sections.
  print("Error: '2025_JAN_16_PUP_TAGUIG_BSA.sav' not found. Please upload the file to your Colab environment.")
except Exception as e:
  print(f"An error occurred: {e}")

# %%
# df: This is your variable, representing the DataFrame that holds your data. Think of a DataFrame like a spreadsheet or a table, where your data is organized in rows and columns. It was created when you read in data using the pyreadstat.read_sav function in a previous line of code.
# head(10): This is a method you apply to your DataFrame. It tells Python to display the first 10 rows of your data.
df.head(10)
# Out:
#   Age PUP Batch Firm                                            Company   A1  \
# 0   2   3     3    1               Punongbayan & Araullo Grant Thornton  4.0
# 1   3   7     1    2                                    Josan Farms Inc  3.0
# 2   2   7     1    2                              Beko Philippines Inc.  4.0
# 3   2   6     3    1  Punong Bayan & Araullo (Grant Thornton Philipp...  4.0
# 4   3   7     1    2                                     Foundever Inc.  4.0
# 5   3   3     2    2                      Universal Rural Bank of Lopez  2.0
# 6   2   3     2    2                Cooperative Bank of Quezon Province  4.0
# 7   2   3     2    2                Cooperative Bank of Quezon Province  3.0
# 8   2   3     2    1       Universal Rural Bank of Lopez (Quezon), Inc.  4.0
# 9   2   3     2    2                 Universal Rural Bank of Lopez Inc.  4.0
#
#     A2   A3   A4   A5  AA1  AA2  AA3  AA4  AA5
# 0  4.0  4.0  4.0  4.0  4.0  4.0  4.0  4.0  4.0
# ...

# %%
# prompt: chage the labels in the x axis 1 as A, 2 as B, and 3 as C

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install pyreadstat

try:
  df, meta = pyreadstat.read_sav("2025_JAN_16_PUP_TAGUIG_BSA.sav")
  df.head(10)
except FileNotFoundError:
  print("Error: '2025_JAN_16_PUP_TAGUIG_BSA.sav' not found. Please upload the file to your Colab environment.")
except Exception as e:
  print(f"An error occurred: {e}")
df.head(10)

# Create a simple bar chart for the 'Age' column
plt.figure(figsize=(8, 5))
ax = df['Age'].value_counts().sort_index().plot(kind='bar', color='blue', edgecolor='black')
plt.title('Age Distribution', fontsize=14)
plt.xlabel('')  # Set the x-axis label to an empty string
plt.ylabel('')  # Set the y-axis label to an empty string

# Customize x-axis labels
labels = {1: '18-20 years old', 2: '21-23 years old', 3: '24-26 years old'}
plt.xticks(ticks=range(len(labels)), labels=[labels.get(x, str(x)) for x in range(1, 4)], rotation=0)


plt.grid(axis='y', linestyle='', alpha=0.7)

# Remove top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add frequency and percentage above each bar
total = len(df['Age'])
for p in ax.patches:
    height = p.get_height()
    percentage = '{:.2f}%'.format(100 * height / total)  # Format percentage to 2 decimal places
    ax.text(p.get_x() + p.get_width() / 2, height + 1,
            f'{int(height)} ({percentage})',  # Change the text format
            ha='center', va='bottom', fontsize=10)

plt.show()
