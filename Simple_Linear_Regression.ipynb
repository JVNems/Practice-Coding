# %% [markdown]
# <a href="https://colab.research.google.com/github/JVNems/Practice-Coding/blob/main/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **I. Importing Relevant Modules for Regression**

# %%
# Import necessary libraries
import pandas as pd  # Used for data manipulation and analysis
import numpy as np  # Used for numerical operations
import matplotlib.pyplot as plt  # Used for data visualization
import seaborn as sns  # Used for enhanced data visualization
from sklearn.model_selection import train_test_split  # Used for splitting data into training and testing sets
from sklearn.linear_model import LinearRegression  # Used for linear regression modeling
from sklearn.metrics import mean_squared_error, r2_score  # Used for evaluating regression model performance

# %% [markdown]
# # **II. Importing CSV Files**

# %%
# prompt: i want to import files csv /content/IceCreamData.csv


# Load the CSV file into a pandas DataFrame.
df = pd.read_csv('/content/IceCreamData.csv')

# %% [markdown]
# # **III. Preview the data**

# %%
# Display the DataFrame
df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
df.tail()
# Out:
#      Temperature     Revenue
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
# prompt: calculate the average and maximun of temperature and revenue

# Calculate the average temperature
average_temp = df['Temperature'].mean()
print(f"Average Temperature: {average_temp}")

# Calculate the maximum temperature
max_temp = df['Temperature'].max()
print(f"Maximum Temperature: {max_temp}")

# Calculate the average revenue
average_revenue = df['Revenue'].mean()
print(f"Average Revenue: {average_revenue}")

# Calculate the maximum revenue
max_revenue = df['Revenue'].max()
print(f"Maximum Revenue: {max_revenue}")
# Out:
# Average Temperature: 22.232225113404002
# Maximum Temperature: 45.0
# Average Revenue: 521.57077669154
# Maximum Revenue: 1000.0

# %% [markdown]
# # **IV.Visualize Data**

# %%
# prompt: create a scatter plot, and add line correspondin the plot

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temperature', y='Revenue', data=df, color='blue', label='Data Points')

# Fit a linear regression model
X = df[['Temperature']]
y = df['Revenue']
model = LinearRegression()
model.fit(X, y)

# Predict revenue based on temperature
y_pred = model.predict(X)

# Add the regression line to the plot
plt.plot(X, y_pred, color='red', label='Regression Line')

# Customize the plot
plt.title('Temperature vs. Revenue')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # **V. Train the Data**

# %%
# prompt: assign the temperature and y the revenur

X = df[['Temperature']]
Y = df['Revenue']

# %%
X = np.array(X)
Y = np.array(Y)

# %%
# prompt: RESHAPE THE X AND Y

X = X.reshape(-1,1)
Y = Y.reshape(-1,1)
X.shape
Y.shape
# Out:
# (500, 1)

# %%
# prompt: use train split

# Split data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Print the shapes of the resulting sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (400, 1)
# X_test shape: (100, 1)
# Y_train shape: (400, 1)
# Y_test shape: (100, 1)

# %% [markdown]
# # **Another Example**

# %% [markdown]
# # **VI. Simple Linear Regression**

# %%
# prompt: perform simple linear regression using sklearn, and display necessaty values

# Import necessary libraries
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming X and Y are already defined as in the provided code
# X = df[['Temperature']]
# Y = df['Revenue']
# X = np.array(X)
# Y = np.array(Y)
# X = X.reshape(-1, 1)
# Y = Y.reshape(-1, 1)

# Split the data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)

# Make predictions
Y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

# Print the model coefficients
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Coefficients: [[21.38197386]]
# Intercept: [46.80464128]
# Mean Squared Error: 652.5200612979734
# R-squared: 0.9771532792713993
